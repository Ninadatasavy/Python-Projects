# %%
import pandas as pd

# %%
df = pd.read_csv('Twelve_Year_Guardian_League_Table.csv')

# %%
df
# Out:
#       Year  Rank   Institution Satisfied with Course Satisfied with Teaching  \
# 0     2021    20      Aberdeen                  87.1                    86.1
# 1     2020    34      Aberdeen                  86.1                    87.3
# 2     2019    51      Aberdeen                  86.9                    88.0
# 3     2018    46      Aberdeen                  86.7                    88.2
# 4     2017    36      Aberdeen                  84.8                    86.6
# ...    ...   ...           ...                   ...                     ...
# 1430  2014    94  York St John                  82.7                    86.0
# 1431  2013    98  York St John                  84.0                    87.0
# 1432  2012    96  York St John                  81.0                    84.0
# 1433  2011    90  York St John                  80.0                    83.0
# 1434  2022    84  York St John                  81.1                    83.6
#
# ...

# %%
Innocent = pd.read_excel('The best UK universities 2023 – rankings.xlsx')

# %%
Innocent
# Out:
#       2023   2022                 Institution  Guardian score/100  \
# 0      1.0    3.0                  St Andrews               100.0
# 1      2.0    1.0                      Oxford                99.4
# 2      3.0    2.0                   Cambridge                98.1
# 3      4.0    4.0  London School of Economics                95.2
# 4      5.0    7.0            Imperial College                89.3
# ..     ...    ...                         ...                 ...
# 120  116.0  119.0    Canterbury Christ Church                54.2
# 121  116.0  110.0                 Westminster                54.2
# 122  119.0  120.0            West of Scotland                53.9
# 123  120.0  118.0                 De Montfort                53.4
# 124  121.0  121.0                Bedfordshire                34.6
#
#      Satisfied with course  Satisfied with teaching  Satisfied with feedback  \
# 0                     91.6                     91.6                     77.8
# ...

# %%
df.head()
# Out:
#    Year  Rank Institution Satisfied with Course Satisfied with Teaching  \
# 0  2021    20    Aberdeen                  87.1                    86.1
# 1  2020    34    Aberdeen                  86.1                    87.3
# 2  2019    51    Aberdeen                  86.9                    88.0
# 3  2018    46    Aberdeen                  86.7                    88.2
# 4  2017    36    Aberdeen                  84.8                    86.6
#
#   Satisfied with Feedback Student to Staff Ratio Spend per Student  \
# 0                    69.5                   16.2       4.400000095
# 1                    71.0                   16.1               4.3
# 2                    67.7                   15.4               4.5
# 3                    68.3                   14.9               4.5
# 4                    65.1                   13.5               5.8
#
#    Average Entry Tariff Value Added Score  Career after 15 months  \
# ...

# %%
df.tail()
# Out:
#       Year  Rank   Institution Satisfied with Course Satisfied with Teaching  \
# 1430  2014    94  York St John                  82.7                    86.0
# 1431  2013    98  York St John                  84.0                    87.0
# 1432  2012    96  York St John                  81.0                    84.0
# 1433  2011    90  York St John                  80.0                    83.0
# 1434  2022    84  York St John                  81.1                    83.6
#
#      Satisfied with Feedback Student to Staff Ratio Spend per Student  \
# 1430                    67.7                   20.9               5.9
# 1431                    71.0                   21.4               5.4
# 1432                    72.0                   21.2               5.8
# 1433                    69.0                   20.2               5.3
# 1434                    77.1                   18.1       3.400000095
#
#       Average Entry Tariff Value Added Score  Career after 15 months  \
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Rank', 'Institution', 'Satisfied with Course',
#        'Satisfied with Teaching', 'Satisfied with Feedback',
#        'Student to Staff Ratio', 'Spend per Student', 'Average Entry Tariff',
#        'Value Added Score', 'Career after 15 months', 'Continuation',
#        'Guardian Score'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Year                         int64
# Rank                         int64
# Institution                 object
# Satisfied with Course       object
# Satisfied with Teaching     object
# Satisfied with Feedback     object
# Student to Staff Ratio      object
# Spend per Student           object
# Average Entry Tariff       float64
# Value Added Score           object
# Career after 15 months     float64
# Continuation               float64
# Guardian Score             float64
# dtype: object

# %%
df.shape
# Out:
# (1435, 13)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1435, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1435 entries, 0 to 1434
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     1435 non-null   int64
#  1   Rank                     1435 non-null   int64
#  2   Institution              1435 non-null   object
#  3   Satisfied with Course    1426 non-null   object
#  4   Satisfied with Teaching  1426 non-null   object
#  5   Satisfied with Feedback  1425 non-null   object
#  6   Student to Staff Ratio   1435 non-null   object
#  7   Spend per Student        1427 non-null   object
#  8   Average Entry Tariff     1434 non-null   float64
#  9   Value Added Score        1434 non-null   object
#  10  Career after 15 months   1434 non-null   float64
#  11  Continuation             484 non-null    float64
#  12  Guardian Score           1435 non-null   float64
# dtypes: float64(4), int64(2), object(7)
# ...

# %%
df.describe()
# Out:
#              Year         Rank  Average Entry Tariff  Career after 15 months  \
# count  1435.00000  1435.000000           1434.000000             1434.000000
# mean   2016.52892    60.149129            256.018550               68.576987
# std       3.45660    34.527394            121.262603               11.199642
# min    2011.00000     1.000000             92.400000               34.000000
# 25%    2014.00000    30.000000            136.000000               60.000000
# 50%    2017.00000    60.000000            258.250000               69.200000
# 75%    2020.00000    90.000000            334.750000               77.900000
# max    2022.00000   121.000000            615.800000               96.000000
#
#        Continuation  Guardian Score
# count    484.000000     1435.000000
# mean      91.308471       59.827666
# std        3.724830       13.061554
# min       78.000000       27.900000
# 25%       88.900000       51.200000
# 50%       91.100000       59.300000
# ...

# %%
df.nunique()
# Out:
# Year                        12
# Rank                       121
# Institution                127
# Satisfied with Course      229
# Satisfied with Teaching    186
# Satisfied with Feedback    236
# Student to Staff Ratio     161
# Spend per Student          141
# Average Entry Tariff       892
# Value Added Score          108
# Career after 15 months     355
# Continuation               139
# Guardian Score             488
# dtype: int64

# %%
df['Year'].unique()
# Out:
# array([2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011,
#        2022], dtype=int64)

# %%
df['Rank'].unique()
# Out:
# array([ 20,  34,  51,  46,  36,  41,  43,  38,  45,  33,  48,  87,  68,
#         66,  85,  93, 101, 114, 119, 106, 110,  88,  49,  54,  81, 108,
#         50,  64,  80,  99, 103,  72, 105,  67,  77,  91,  84,  97,  30,
#         29,  22,  27,  25,  75,  78,  47,  63,  55,  57,  82,  74,  79,
#         65,  86,   6,   5,  10,   4,   7,   9,  14,  13,   8, 109, 107,
#         61,  69,  71, 121, 113,  98, 115, 102,  21,  16,  19,  15,  17,
#         24,  83,  60,  90, 120, 116,  56,  73,  52,  42,  89,  62,  11,
#         23,  35,  18,  58,  53,  44,  92, 112,   3,   1,   2, 117, 104,
#         37,  26,  40,  39,  95,  76,  70,  94,  32,  12, 118,  96,  59,
#         28,  31, 100, 111], dtype=int64)

# %% [markdown]
# ## 19/07/2023

# %% [markdown]
# ## Filtering through columns

# %%
Year_Stat = df[['Year','Satisfied with Teaching']]

# %%
Year_Stat
# Out:
#       Year Satisfied with Teaching
# 0     2021                    86.1
# 1     2020                    87.3
# 2     2019                    88.0
# 3     2018                    88.2
# 4     2017                    86.6
# ...    ...                     ...
# 1430  2014                    86.0
# 1431  2013                    87.0
# 1432  2012                    84.0
# 1433  2011                    83.0
# 1434  2022                    83.6
#
# [1435 rows x 2 columns]

# %%
Year_Stat.head(20)
# Out:
#     Year Satisfied with Teaching
# 0   2021                    86.1
# 1   2020                    87.3
# 2   2019                    88.0
# 3   2018                    88.2
# 4   2017                    86.6
# 5   2016                    86.4
# 6   2015                    88.9
# 7   2014                    86.5
# 8   2013                    88.0
# 9   2012                    87.0
# 10  2011                    89.0
# 11  2022                    85.3
# 12  2021                    88.7
# 13  2020                    82.3
# 14  2019                    86.4
# 15  2018                    89.3
# 16  2017                    88.3
# 17  2016                    85.0
# 18  2015                    86.3
# 19  2014                    82.8

# %% [markdown]
# ## Sub Set
# Sub set is to take the set of the data that fulifil a certain conditions

# %%
Year = df[df.Year == 2017]

# %%
Year
# Out:
#       Year  Rank     Institution Satisfied with Course  \
# 4     2017    36        Aberdeen                  84.8
# 16    2017    85  Abertay Dundee                  87.4
# 28    2017   108     Aberystwyth                  82.4
# 40    2017    66   Anglia Ruskin                  86.0
# 52    2017    29           Aston                  87.9
# ...    ...   ...             ...                   ...
# 1375  2017   112     Westminster                  81.3
# 1387  2017    63      Winchester                  90.6
# 1403  2017    95       Worcester                  87.3
# 1415  2017    19            York                  87.0
# 1427  2017   104    York St John                  86.7
#
#      Satisfied with Teaching Satisfied with Feedback Student to Staff Ratio  \
# 4                       86.6                    65.1                   13.5
# 16                      88.3                    72.4                   19.3
# ...

# %% [markdown]
# ## Export data to csv

# %%
Year.to_csv('Year_2017.csv')

# %%
Year.to_csv('Year_2018.csv')

# %%
year_and_age = df[(df['Year'] == 2017) & (df['Rank']>=25)]

# %%
year_and_age
# Out:
#       Year  Rank       Institution Satisfied with Course  \
# 4     2017    36          Aberdeen                  84.8
# 16    2017    85    Abertay Dundee                  87.4
# 28    2017   108       Aberystwyth                  82.4
# 40    2017    66     Anglia Ruskin                  86.0
# 52    2017    29             Aston                  87.9
# ...    ...   ...               ...                   ...
# 1364  2017   103  West of Scotland                  86.7
# 1375  2017   112       Westminster                  81.3
# 1387  2017    63        Winchester                  90.6
# 1403  2017    95         Worcester                  87.3
# 1427  2017   104      York St John                  86.7
#
#      Satisfied with Teaching Satisfied with Feedback Student to Staff Ratio  \
# 4                       86.6                    65.1                   13.5
# 16                      88.3                    72.4                   19.3
# ...

# %%
YR = year_and_age[['Year','Rank']]

# %%
YR
# Out:
#       Year  Rank
# 4     2017    36
# 16    2017    85
# 28    2017   108
# 40    2017    66
# 52    2017    29
# ...    ...   ...
# 1364  2017   103
# 1375  2017   112
# 1387  2017    63
# 1403  2017    95
# 1427  2017   104
#
# [95 rows x 2 columns]

# %%
df['Year'] = pd.to_datetime(df['Year'])

# %%
df.dtypes
# Out:
# Year                        object
# Rank                         int64
# Institution                 object
# Satisfied with Course       object
# Satisfied with Teaching     object
# Satisfied with Feedback     object
# Student to Staff Ratio      object
# Spend per Student           object
# Average Entry Tariff       float64
# Value Added Score           object
# Career after 15 months     float64
# Continuation               float64
# Guardian Score             float64
# dtype: object

# %%
df.head()
# Out:
#    Year  Rank Institution Satisfied with Course Satisfied with Teaching  \
# 0  2021    20    Aberdeen                  87.1                    86.1
# 1  2020    34    Aberdeen                  86.1                    87.3
# 2  2019    51    Aberdeen                  86.9                    88.0
# 3  2018    46    Aberdeen                  86.7                    88.2
# 4  2017    36    Aberdeen                  84.8                    86.6
#
#   Satisfied with Feedback Student to Staff Ratio Spend per Student  \
# 0                    69.5                   16.2       4.400000095
# 1                    71.0                   16.1               4.3
# 2                    67.7                   15.4               4.5
# 3                    68.3                   14.9               4.5
# 4                    65.1                   13.5               5.8
#
#    Average Entry Tariff Value Added Score  Career after 15 months  \
# ...

# %% [markdown]
# ## Indexing in Dataframe
# Looking at something called iloc and loc

# %%
## iloc uses intger while loc uses object values to slice positions.

# %%
df.iloc[1,-1]
## This will return the last number in the table
# Out:
# 62.5

# %%
df.iloc[1]
# Out:
# Year                           2020
# Rank                             34
# Institution                Aberdeen
# Satisfied with Course          86.1
# Satisfied with Teaching        87.3
# Satisfied with Feedback        71.0
# Student to Staff Ratio         16.1
# Spend per Student               4.3
# Average Entry Tariff          184.0
# Value Added Score               6.8
# Career after 15 months         81.0
# Continuation                   91.7
# Guardian Score                 62.5
# Name: 1, dtype: object

# %%
df.iloc[1:15]
# Out:
#     Year  Rank     Institution Satisfied with Course Satisfied with Teaching  \
# 1   2020    34        Aberdeen                  86.1                    87.3
# 2   2019    51        Aberdeen                  86.9                    88.0
# 3   2018    46        Aberdeen                  86.7                    88.2
# 4   2017    36        Aberdeen                  84.8                    86.6
# 5   2016    41        Aberdeen                  86.4                    86.4
# 6   2015    41        Aberdeen                  88.0                    88.9
# 7   2014    43        Aberdeen                  88.1                    86.5
# 8   2013    38        Aberdeen                  88.0                    88.0
# 9   2012    45        Aberdeen                  88.0                    87.0
# 10  2011    33        Aberdeen                  89.0                    89.0
# 11  2022    20        Aberdeen                  86.1                    85.3
# ...

# %%
#df.loc[row_label,column_label]
df.loc[6,'Satisfied with Course']
# Out:
# '88.0'

# %%
##df.loc[row_label:row_label]
df.loc[5:15]
# Out:
#     Year  Rank     Institution Satisfied with Course Satisfied with Teaching  \
# 5   2016    41        Aberdeen                  86.4                    86.4
# 6   2015    41        Aberdeen                  88.0                    88.9
# 7   2014    43        Aberdeen                  88.1                    86.5
# 8   2013    38        Aberdeen                  88.0                    88.0
# 9   2012    45        Aberdeen                  88.0                    87.0
# 10  2011    33        Aberdeen                  89.0                    89.0
# 11  2022    20        Aberdeen                  86.1                    85.3
# 12  2021    48  Abertay Dundee                  88.1                    88.7
# 13  2020    87  Abertay Dundee                  78.2                    82.3
# 14  2019    68  Abertay Dundee                  85.3                    86.4
# 15  2018    66  Abertay Dundee                  88.8                    89.3
#
# ...

# %%
df.loc[90:100]
# Out:
#      Year  Rank   Institution Satisfied with Course Satisfied with Teaching  \
# 90   2015    69      Bath Spa                  87.8                    89.7
# 91   2014    78      Bath Spa                  84.6                    87.8
# 92   2013    71      Bath Spa                  84.0                    88.0
# 93   2012    65      Bath Spa                  79.0                    86.0
# 94   2011    67      Bath Spa                  83.0                    88.0
# 95   2022    91      Bath Spa                  75.4                      80
# 96   2021   121  Bedfordshire                  76.2                    82.3
# 97   2020   121  Bedfordshire                  81.7                    84.2
# 98   2019   113  Bedfordshire                  81.6                    83.2
# 99   2018    98  Bedfordshire                  84.4                    84.0
# 100  2017   113  Bedfordshire                  81.6                    84.2
#
# ...

# %%
#slicing multiple columns
df.loc[range['name','sex']]

# %%
loca = df.loc[23:30,['Institution','Guardian Score']]

# %%
loca
# Out:
#        Institution  Guardian Score
# 23  Abertay Dundee            61.2
# 24     Aberystwyth            61.1
# 25     Aberystwyth            55.0
# 26     Aberystwyth            66.6
# 27     Aberystwyth            53.8
# 28     Aberystwyth            43.6
# 29     Aberystwyth            44.2
# 30     Aberystwyth            43.8

# %%
loca = df.loc[23:30,['Institution','Guardian Score']]

# %%
##df.loc[[0,1,8,80],['column_name',...]]

# %%
df.loc[[2,26,29,80,97],['Year','Institution','Guardian Score',]]
# Out:
#     Year   Institution  Guardian Score
# 2   2019      Aberdeen            64.9
# 26  2019   Aberystwyth            66.6
# 29  2016   Aberystwyth            44.2
# 80  2013          Bath            75.8
# 97  2020  Bedfordshire            27.9

# %%
## finding the Mean

# %%
Mean = df[["Guardian Score","Institution"]].mean(axis = 1)
# Out:
# C:\Users\njoku\AppData\Local\Temp\ipykernel_14928\1240232485.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Mean = df[["Guardian Score","Institution"]].mean(axis = 1)

# %%
Mean
# Out:
# 0       68.1
# 1       62.5
# 2       64.9
# 3       62.3
# 4       66.1
#         ...
# 1430    47.8
# 1431    43.8
# 1432    46.5
# 1433    49.9
# 1434    62.7
# Length: 1435, dtype: float64

# %% [markdown]
# ## Dealing with missing values

# %%
df.isnull().sum()
# Out:
# Year                         0
# Rank                         0
# Institution                  0
# Satisfied with Course        9
# Satisfied with Teaching      9
# Satisfied with Feedback     10
# Student to Staff Ratio       0
# Spend per Student            8
# Average Entry Tariff         1
# Value Added Score            1
# Career after 15 months       1
# Continuation               951
# Guardian Score               0
# dtype: int64

# %% [markdown]
# ## How to drop missing value

# %%
gas = df.dropna()

# %%
gas
# Out:
#       Year  Rank     Institution Satisfied with Course  \
# 0     2021    20        Aberdeen                  87.1
# 1     2020    34        Aberdeen                  86.1
# 2     2019    51        Aberdeen                  86.9
# 11    2022    20        Aberdeen                  86.1
# 12    2021    48  Abertay Dundee                  88.1
# ...    ...   ...             ...                   ...
# 1422  2022    18            York                  81.6
# 1423  2021    91    York St John                  85.6
# 1424  2020   107    York St John                  85.1
# 1425  2019   119    York St John                  82.2
# 1434  2022    84    York St John                  81.1
#
#      Satisfied with Teaching Satisfied with Feedback Student to Staff Ratio  \
# 0                       86.1                    69.5                   16.2
# 1                       87.3                    71.0                   16.1
# ...

# %%
gas.to_csv('gas.csv')

# %%
df
# Out:
#       Year  Rank   Institution Satisfied with Course Satisfied with Teaching  \
# 0     2021    20      Aberdeen                  87.1                    86.1
# 1     2020    34      Aberdeen                  86.1                    87.3
# 2     2019    51      Aberdeen                  86.9                    88.0
# 3     2018    46      Aberdeen                  86.7                    88.2
# 4     2017    36      Aberdeen                  84.8                    86.6
# ...    ...   ...           ...                   ...                     ...
# 1430  2014    94  York St John                  82.7                    86.0
# 1431  2013    98  York St John                  84.0                    87.0
# 1432  2012    96  York St John                  81.0                    84.0
# 1433  2011    90  York St John                  80.0                    83.0
# 1434  2022    84  York St John                  81.1                    83.6
#
# ...
